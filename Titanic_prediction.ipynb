# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Titanic_dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# AgeGroup         0
# dtype: int64

# %% [markdown]
# # check if there any duplicate value exixt if exist then remove them

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # remnove the null value with median

# %%
x=df['Age'].median()
df.fillna({'Age':x},inplace=True)

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  AgeGroup     891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)
# Out:
# C:\Users\surje\AppData\Local\Temp\ipykernel_8328\3717664479.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
#  12  AgeGroup     891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
df['Cabin'].fillna(df['Cabin'].mode()[0],inplace=True)
# Out:
# C:\Users\surje\AppData\Local\Temp\ipykernel_8328\3668765300.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cabin'].fillna(df['Cabin'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# AgeGroup       0
# dtype: int64

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Standarize text

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
#  12  AgeGroup     891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
df['Name']=df['Name'].str.strip().str.title().str.lower()

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            braund, mr. owen harris    male  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                             heikkinen, miss. laina  female  26.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked AgeGroup
# 0      0         A/5 21171   7.2500  B96 B98        S    Adult
# 1      0          PC 17599  71.2833      C85        C    Adult
# 2      0  STON/O2. 3101282   7.9250  B96 B98        S    Adult

# %%
df[df.select_dtypes(include='object').columns]=df.select_dtypes(include='object').apply(lambda col:col.str.strip().str.title().str.lower())

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            braund, mr. owen harris    male  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                             heikkinen, miss. laina  female  26.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked AgeGroup
# 0      0         a/5 21171   7.2500  b96 b98        s    adult
# 1      0          pc 17599  71.2833      c85        c    adult
# 2      0  ston/o2. 3101282   7.9250  b96 b98        s    adult

# %% [markdown]
# # correcting spelling and typos

# %%
from textblob import TextBlob
for col in df.select_dtypes(include='object').columns:
    df[col]=df[col].apply(lambda x: str(TextBlob(str(x)).correct()) if pd.notnull(x) else x)

# %%
df.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# # featuer Engineering

# %%
df['HasCabin'] = df['Cabin'].apply(lambda x: 0 if x == 'by by' else 1)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                             brand, mr. owen harris    male  22.0      1
# 1  comings, mrs. john bradley (florence brings th...  female  38.0      1
# 2                              heikkinen, miss. lain  female  26.0      0
# 3       futrelle, mrs. jacques heath (lily may feel)  female  35.0      1
# 4                           allen, mr. william henry    male  35.0      0
# 5                                   moran, mr. james    male  28.0      0
# ...

# %% [markdown]
# # Outlier Analysis

# %%
# we do iqr and boxplot for initial detection

# %% [markdown]
# IQR

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'AgeGroup', 'HasCabin'],
#       dtype='object')

# %%
def iqr_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers, lower_bound, upper_bound


numeric_col=['Age', 'SibSp','Parch','Fare']
for col in numeric_col:
    outliers, low, high = iqr_outliers(df, col)
    print(f"{col}: {outliers.shape[0]} outliers | bounds: ({low}, {high})")
# Out:
# Age: 66 outliers | bounds: (2.5, 54.5)
# SibSp: 46 outliers | bounds: (-1.5, 2.5)
# Parch: 213 outliers | bounds: (0.0, 0.0)
# Fare: 116 outliers | bounds: (-26.724, 65.6344)

# %%
df['FamilySize']=df['SibSp']+df['Parch']+1

# %%
df['IsAlone']=df['FamilySize'].apply(lambda x : 1 if x==0 else 0)

# %%
df['AgeGroup'] = pd.cut(df['Age'],
                        bins=[0, 12, 18, 55, 100],
                        labels=['Child', 'Teen', 'Adult', 'Senior'])

# %%
df['FareBin'] = pd.qcut(df['Fare'], 4, labels=['Low', 'Medium', 'High', 'VeryHigh'])

# %%
# 5. Cabin features
df['HasCabin'] = df['Cabin'].apply(lambda x: 0 if x in ['by by', 'nan', None] else 1)
df['CabinDeck'] = df['Cabin'].apply(lambda x: x[0] if x not in ['by by', 'nan', None] else 'M')

# %%
# 6. Title from Name
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\surje\AppData\Local\Temp\ipykernel_8328\2256810579.py:2: SyntaxWarning: invalid escape sequence '\.'
#   df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                             brand, mr. owen harris    male  22.0      1
# 1  comings, mrs. john bradley (florence brings th...  female  38.0      1
# 2                              heikkinen, miss. lain  female  26.0      0
# 3       futrelle, mrs. jacques heath (lily may feel)  female  35.0      1
# 4                           allen, mr. william henry    male  35.0      0
# 5                                   moran, mr. james    male  28.0      0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
sns.boxplot(x=df['Fare'])
plt.title("Boxplot of Fare")
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12,8))

sns.boxplot(x=df['Age'], ax=axes[0,0])
axes[0,0].set_title("Age")

sns.boxplot(x=df['SibSp'], ax=axes[0,1])
axes[0,1].set_title("SibSp")

sns.boxplot(x=df['Parch'], ax=axes[1,0])
axes[1,0].set_title("Parch")

sns.boxplot(x=df['Fare'], ax=axes[1,1])
axes[1,1].set_title("Fare")

plt.tight_layout()
plt.show()

# %% [markdown]
# # data exploration and Insight (EDA)

# %%
sns.barplot(x='Sex',y='Survived',data=df)
sns.barplot(x="Pclass", y="Survived", data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# # Encoding

# %%
# label encoding for sex column

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Sex']=le.fit_transform(df['Sex'])

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                             brand, mr. owen harris    1  22.0      1      0
# 1  comings, mrs. john bradley (florence brings th...    0  38.0      1      0
#
#       Ticket     Fare  Cabin Embarked AgeGroup  HasCabin  FamilySize  IsAlone  \
# 0  a/5 21171   7.2500  by by        s    Adult         0           2        0
# 1   pp 17599  71.2833    can        c    Adult         1           2        0
#
#     FareBin CabinDeck Title
# 0       Low         M    mr
# 1  VeryHigh         c   mrs

# %%
df['AgeGroup']=le.fit_transform(df['AgeGroup'])

# %%
df['FareBin']=le.fit_transform(df['FareBin'])

# %%
# One-hot encoding in Emberked ,CabinDeck,Title

# %%
# embarked
df=pd.get_dummies(df,columns=['Embarked'],prefix='Embarked',drop_first=True)
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                             brand, mr. owen harris    1  22.0      1      0
# 1  comings, mrs. john bradley (florence brings th...    0  38.0      1      0
#
#       Ticket     Fare  Cabin  AgeGroup  HasCabin  FamilySize  IsAlone  \
# 0  a/5 21171   7.2500  by by         0         0           2        0
# 1   pp 17599  71.2833    can         0         1           2        0
#
#    FareBin CabinDeck Title  Embarked_q  Embarked_s
# 0        1         M    mr       False        True
# 1        3         c   mrs       False       False

# %%
# CabinDeck
df=pd.get_dummies(df,columns=['CabinDeck'],prefix='CabinDeck',drop_first=True)
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                             brand, mr. owen harris    1  22.0      1      0
# 1  comings, mrs. john bradley (florence brings th...    0  38.0      1      0
#
#       Ticket     Fare  ... Embarked_q  Embarked_s  CabinDeck_a  CabinDeck_b  \
# 0  a/5 21171   7.2500  ...      False        True        False        False
# 1   pp 17599  71.2833  ...      False       False        False        False
#
#    CabinDeck_c  CabinDeck_d CabinDeck_e  CabinDeck_f  CabinDeck_g  CabinDeck_t
# 0        False        False       False        False        False        False
# 1         True        False       False        False        False        False
#
# [2 rows x 27 columns]

# %%
# Title
df=pd.get_dummies(df,columns=['Title'],prefix='Title',drop_first=True)
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                             brand, mr. owen harris    1  22.0      1      0
# 1  comings, mrs. john bradley (florence brings th...    0  38.0      1      0
#
#       Ticket     Fare  ... Title_major  Title_master  Title_me  Title_miss  \
# 0  a/5 21171   7.2500  ...       False         False     False       False
# 1   pp 17599  71.2833  ...       False         False     False       False
#
#    Title_mlle  Title_mr  Title_mrs  Title_ms  Title_rev  Title_sir
# 0       False      True      False     False      False      False
# 1       False     False       True     False      False      False
#
# [2 rows x 42 columns]

# %% [markdown]
# # modling

# %% [markdown]
#  1. Drop Unnessary columns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'AgeGroup', 'HasCabin',
#        'FamilySize', 'IsAlone', 'FareBin', 'Embarked_q', 'Embarked_s',
#        'CabinDeck_a', 'CabinDeck_b', 'CabinDeck_c', 'CabinDeck_d',
#        'CabinDeck_e', 'CabinDeck_f', 'CabinDeck_g', 'CabinDeck_t', 'Title_col',
#        'Title_countess', 'Title_don', 'Title_dr', 'Title_jonkheer',
#        'Title_lady', 'Title_major', 'Title_master', 'Title_me', 'Title_miss',
#        'Title_mlle', 'Title_mr', 'Title_mrs', 'Title_ms', 'Title_rev',
#        'Title_sir'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 42 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PassengerId     891 non-null    int64
#  1   Survived        891 non-null    int64
#  2   Pclass          891 non-null    int64
#  3   Name            891 non-null    object
#  4   Sex             891 non-null    int64
#  5   Age             891 non-null    float64
#  6   SibSp           891 non-null    int64
#  7   Parch           891 non-null    int64
#  8   Ticket          891 non-null    object
#  9   Fare            891 non-null    float64
#  10  Cabin           891 non-null    object
#  11  AgeGroup        891 non-null    int64
#  12  HasCabin        891 non-null    int64
#  13  FamilySize      891 non-null    int64
#  14  IsAlone         891 non-null    int64
#  15  FareBin         891 non-null    int64
#  16  Embarked_q      891 non-null    bool
# ...

# %%
df=df.drop(columns=['PassengerId','Name','Ticket','Cabin'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 38 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        891 non-null    int64
#  1   Pclass          891 non-null    int64
#  2   Sex             891 non-null    int64
#  3   Age             891 non-null    float64
#  4   SibSp           891 non-null    int64
#  5   Parch           891 non-null    int64
#  6   Fare            891 non-null    float64
#  7   AgeGroup        891 non-null    int64
#  8   HasCabin        891 non-null    int64
#  9   FamilySize      891 non-null    int64
#  10  IsAlone         891 non-null    int64
#  11  FareBin         891 non-null    int64
#  12  Embarked_q      891 non-null    bool
#  13  Embarked_s      891 non-null    bool
#  14  CabinDeck_a     891 non-null    bool
#  15  CabinDeck_b     891 non-null    bool
#  16  CabinDeck_c     891 non-null    bool
# ...

# %%
x = df.drop('Survived', axis=1)
y = df['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2 ,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42)
}

# %%
results = {}

for name, model in models.items():
    # Train
    model.fit(x_train, y_train)
    # Predict
    y_pred = model.predict(x_test)
    y_proba = model.predict_proba(x_test)[:,1] if hasattr(model, "predict_proba") else None
    
    # Metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_proba) if y_proba is not None else None
    
    # Save results
    results[name] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1": f1,
        "ROC-AUC": roc_auc
    }

# Show results
import pandas as pd
results_df = pd.DataFrame(results).T
print(results_df)
# Out:
#                      Accuracy  Precision    Recall        F1   ROC-AUC
# Logistic Regression  0.815642   0.766234  0.797297  0.781457  0.882497
# Random Forest        0.804469   0.760000  0.770270  0.765101  0.888288
# Decision Tree        0.759777   0.696203  0.743243  0.718954  0.763192

# %% [markdown]
# # as we see that logistic regression is good for smaall data set and it f1 score is high and roc curve is close to random forest

# %%
final_model = LogisticRegression(max_iter=1000, random_state=42)
final_model.fit(x_train, y_train)

# Predictions
y_pred = final_model.predict(x_test)
y_proba = final_model.predict_proba(x_test)[:,1]

# %%
# Evaluating matrics again
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay
import matplotlib.pyplot as plt
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1:", f1_score(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_proba))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.show()

# ROC Curve
RocCurveDisplay.from_estimator(final_model, x_test, y_test)
plt.show()
# Out:
# Accuracy: 0.8156424581005587
# Precision: 0.7662337662337663
# Recall: 0.7972972972972973
# F1: 0.7814569536423841
# ROC-AUC: 0.8824967824967825

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'AgeGroup', 'HasCabin', 'FamilySize', 'IsAlone', 'FareBin',
#        'Embarked_q', 'Embarked_s', 'CabinDeck_a', 'CabinDeck_b', 'CabinDeck_c',
#        'CabinDeck_d', 'CabinDeck_e', 'CabinDeck_f', 'CabinDeck_g',
#        'CabinDeck_t', 'Title_col', 'Title_countess', 'Title_don', 'Title_dr',
#        'Title_jonkheer', 'Title_lady', 'Title_major', 'Title_master',
#        'Title_me', 'Title_miss', 'Title_mlle', 'Title_mr', 'Title_mrs',
#        'Title_ms', 'Title_rev', 'Title_sir'],
#       dtype='object')

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
import joblib

# Numeric columns to scale
numeric_features = ["Pclass", "Age", "SibSp", "Parch", "Fare"]

# Preprocessor: scale numeric, passthrough everything else
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features)
    ],
    remainder="passthrough"  # keep all engineered features (Embarked_q, CabinDeck, Titles, etc.)
)

# Build pipeline: preprocessing + logistic regression
pipeline = Pipeline([
    ("preprocess", preprocessor),
    ("model", LogisticRegression(max_iter=1000))
])

# Fit pipeline on training data (with engineered columns)
pipeline.fit(x_train, y_train)

# Save pipeline
joblib.dump(pipeline, "titanic_logistic_model.pkl")
print("Model saved as titanic_logistic_model.pkl")
# Out:
# Model saved as titanic_logistic_model.pkl

# %% [markdown]
# # lets load the modle to see the accuracy of model

# %%
# Load the saved model
loaded_model = joblib.load("titanic_logistic_model.pkl")

# Test prediction
y_pred_loaded = loaded_model.predict(x_test)
print("Accuracy after loading:", accuracy_score(y_test, y_pred_loaded))
# Out:
# Accuracy after loading: 0.8156424581005587
